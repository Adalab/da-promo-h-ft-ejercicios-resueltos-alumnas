# %%
# # Ejercicios

#1.  Utilizando la API de Balldontlie extrae la siguiente información. 

# El nombre, apellido y equipo de cada uno de los jugadores que tenemos en la NBA. Para eso tendrás que usar el [siguiente](http://api.balldontlie.io/v1/players) endpoint. 
#Extrae información de los jugadores. Devuelve los resultados en un DataFrame. Te deberá quedar algo parecido a esto:

![jugadores](https://github.com/Adalab/data_imagenes/blob/main/Modulo-2/api's_clase_invertida_jugadores.png?raw=true)

# Extrae información de todos los equipos, con la informacion que estos mismos traen,puedes encontrar la conferencia a la que pertenece, la ciudad, el nombre y su abreviacion. 
# En este caso ustedes deben buscar por dentro de la pagina cual es la API que corresponderia a esta busqueda!!. Tambien dejar la informacion como un dataframe similar al ejemplo anterior.
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
# !pip install requests
# !pip install pandas

# %%
import requests
import pandas as pd
import re

# %%
api_key=f"b8d18369-0af1-4aaf-9310-34789d0f525f"

url_jugadores= f"http://api.balldontlie.io/v1/players"

headers ={'Authorization': api_key}

# %%
res_jugadores = requests.get(f"http://api.balldontlie.io/v1/players", headers = {'Authorization': api_key})

# %%
#    def llamar_api(endpoint):   ###### crero que da error porque ya lo estoy llamando arriba el requests.get y aqui lo hago otra vez
  #      llamada= requests.get(endpoint)
  #      print(f"La llamada nos ha dado una respuesta del tipo {llamada.status_code}")
  #      if llamada.status_code !=200:
  #          print(f"El motivo por el que ha dado error es {llamada.reason}")

  #     else:
  #         return llamada.json()

# %%
url_jugadores= f"http://api.balldontlie.io/v1/players"
res_jugadores=res_jugadores.json()

# %%
print(res_jugadores)
# Out:
# {'data': [{'id': 1, 'first_name': 'Alex', 'last_name': 'Abrines', 'position': 'G', 'height': '6-6', 'weight': '190', 'jersey_number': '8', 'college': 'FC Barcelona', 'country': 'Spain', 'draft_year': 2013, 'draft_round': 2, 'draft_number': 32, 'team': {'id': 21, 'conference': 'West', 'division': 'Northwest', 'city': 'Oklahoma City', 'name': 'Thunder', 'full_name': 'Oklahoma City Thunder', 'abbreviation': 'OKC'}}, {'id': 2, 'first_name': 'Jaylen', 'last_name': 'Adams', 'position': 'G', 'height': '6-0', 'weight': '225', 'jersey_number': '10', 'college': 'St. Bonaventure', 'country': 'USA', 'draft_year': None, 'draft_round': None, 'draft_number': None, 'team': {'id': 1, 'conference': 'East', 'division': 'Southeast', 'city': 'Atlanta', 'name': 'Hawks', 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL'}}, {'id': 3, 'first_name': 'Steven', 'last_name': 'Adams', 'position': 'C', 'height': '6-11', 'weight': '265', 'jersey_number': '12', 'college': 'Pittsburgh', 'country': 'New Zealand', 'd
# ...

# %%
res_jugadores.keys()
# Out:
# dict_keys(['data', 'meta'])

# %%
res_jugadores["data"]
# Out:
# [{'id': 1,
#   'first_name': 'Alex',
#   'last_name': 'Abrines',
#   'position': 'G',
#   'height': '6-6',
#   'weight': '190',
#   'jersey_number': '8',
#   'college': 'FC Barcelona',
#   'country': 'Spain',
#   'draft_year': 2013,
#   'draft_round': 2,
#   'draft_number': 32,
#   'team': {'id': 21,
#    'conference': 'West',
#    'division': 'Northwest',
#    'city': 'Oklahoma City',
#    'name': 'Thunder',
#    'full_name': 'Oklahoma City Thunder',
#    'abbreviation': 'OKC'}},
#  {'id': 2,
#   'first_name': 'Jaylen',
#   'last_name': 'Adams',
#   'position': 'G',
#   'height': '6-0',
#   'weight': '225',
#   'jersey_number': '10',
#   'college': 'St. Bonaventure',
#   'country': 'USA',
#   'draft_year': None,
#   'draft_round': None,
#   'draft_number': None,
#   'team': {'id': 1,
#    'conference': 'East',
#    'division': 'Southeast',
#    'city': 'Atlanta',
#    'name': 'Hawks',
#    'full_name': 'Atlanta Hawks',
#    'abbreviation': 'ATL'}},
#  {'id': 3,
# ...

# %%
# Extraemos los nombres de la lista de diccionarios de players

nombres_jugadores=[]
for jugador in res_jugadores["data"]:
    nombres_jugadores.append(jugador["first_name"])

# %%
nombres_jugadores
# Out:
# ['Alex',
#  'Jaylen',
#  'Steven',
#  'Bam',
#  'DeVaughn',
#  'LaMarcus',
#  'Rawle',
#  'Grayson',
#  'Jarrett',
#  'Al-Farouq',
#  'Justin',
#  'Kyle',
#  'Ryan',
#  'Ike',
#  'Giannis',
#  'Kostas',
#  'Carmelo',
#  'OG',
#  'Ryan',
#  'Trevor',
#  'D.J.',
#  'Deandre',
#  'Dwayne',
#  'Marvin',
#  'Ron']

# %%
#Extraemos los apellidos de la lista de diccionario de players

apellidos_jugadores=[]
for jugador in res_jugadores["data"]:
    apellidos_jugadores.append(jugador["last_name"])

# %%
apellidos_jugadores
# Out:
# ['Abrines',
#  'Adams',
#  'Adams',
#  'Adebayo',
#  'Akoon-Purcell',
#  'Aldridge',
#  'Alkins',
#  'Allen',
#  'Allen',
#  'Aminu',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anigbogu',
#  'Antetokounmpo',
#  'Antetokounmpo',
#  'Anthony',
#  'Anunoby',
#  'Arcidiacono',
#  'Ariza',
#  'Augustin',
#  'Ayton',
#  'Bacon',
#  'Bagley III',
#  'Baker']

# %%
#Extraemos el equipo de cada jugador de la lista

equipo_jugadores=[]

for jugador in res_jugadores["data"]:
    equipo_jugadores.append(jugador["team"])

# %%
equipo_jugadores
# Out:
# [{'id': 21,
#   'conference': 'West',
#   'division': 'Northwest',
#   'city': 'Oklahoma City',
#   'name': 'Thunder',
#   'full_name': 'Oklahoma City Thunder',
#   'abbreviation': 'OKC'},
#  {'id': 1,
#   'conference': 'East',
#   'division': 'Southeast',
#   'city': 'Atlanta',
#   'name': 'Hawks',
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL'},
#  {'id': 11,
#   'conference': 'West',
#   'division': 'Southwest',
#   'city': 'Houston',
#   'name': 'Rockets',
#   'full_name': 'Houston Rockets',
#   'abbreviation': 'HOU'},
#  {'id': 16,
#   'conference': 'East',
#   'division': 'Southeast',
#   'city': 'Miami',
#   'name': 'Heat',
#   'full_name': 'Miami Heat',
#   'abbreviation': 'MIA'},
#  {'id': 8,
#   'conference': 'West',
#   'division': 'Northwest',
#   'city': 'Denver',
#   'name': 'Nuggets',
#   'full_name': 'Denver Nuggets',
#   'abbreviation': 'DEN'},
#  {'id': 3,
#   'conference': 'East',
#   'division': 'Atlantic',
#   'city': 'Brooklyn',
#   'name': 'Nets',
# ...

# %%
nombre_equipo=[]

for jugador_team in equipo_jugadores:
    nombre_equipo.append(jugador_team["name"])

# %%
nombre_equipo
# Out:
# ['Thunder',
#  'Hawks',
#  'Rockets',
#  'Heat',
#  'Nuggets',
#  'Nets',
#  'Bulls',
#  'Suns',
#  'Cavaliers',
#  'Trail Blazers',
#  'Pacers',
#  'Timberwolves',
#  'Pelicans',
#  'Pacers',
#  'Bucks',
#  'Bulls',
#  'Lakers',
#  'Knicks',
#  'Knicks',
#  'Lakers',
#  'Lakers',
#  'Trail Blazers',
#  'Lakers',
#  'Wizards',
#  'Knicks']

# %%
diccionario_jugadores={"nombre":nombres_jugadores,"apelllido":apellidos_jugadores,"equipo":nombre_equipo }

# %%
df_jugadores=pd.DataFrame(diccionario_jugadores)

# %%
df_jugadores
# Out:
#        nombre      apelllido         equipo
# 0        Alex        Abrines        Thunder
# 1      Jaylen          Adams          Hawks
# 2      Steven          Adams        Rockets
# 3         Bam        Adebayo           Heat
# 4    DeVaughn  Akoon-Purcell        Nuggets
# 5    LaMarcus       Aldridge           Nets
# 6       Rawle         Alkins          Bulls
# 7     Grayson          Allen           Suns
# 8     Jarrett          Allen      Cavaliers
# 9   Al-Farouq          Aminu  Trail Blazers
# 10     Justin       Anderson         Pacers
# 11       Kyle       Anderson   Timberwolves
# 12       Ryan       Anderson       Pelicans
# 13        Ike       Anigbogu         Pacers
# 14    Giannis  Antetokounmpo          Bucks
# 15     Kostas  Antetokounmpo          Bulls
# 16    Carmelo        Anthony         Lakers
# 17         OG        Anunoby         Knicks
# 18       Ryan    Arcidiacono         Knicks
# 19     Trevor          Ariza         Lakers
# ...

# %%
#SOLUCION PROFESOR

# %%
jugadores = {"nombres": [], "apellidos": [], "equipo": []}

res_jugadores = requests.get(f"http://api.balldontlie.io/v1/players", headers = {'Authorization': api_key}) # cada una pone la kpi que haya generado

res_jugadores = res_jugadores.json()


for jugador in res_jugadores["data"]:
    jugadores["nombres"].append(jugador["first_name"])
    jugadores["apellidos"].append(jugador["last_name"])
    jugadores["equipo"].append(jugador["team"]["full_name"])    



df_jugadores = pd.DataFrame(jugadores)
df_jugadores
