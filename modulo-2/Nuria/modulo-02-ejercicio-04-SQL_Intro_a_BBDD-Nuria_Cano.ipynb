# %%
#Import libraries
import pandas as pd

# %%
#open CSV file
pd.set_option('display.max_columns', None)

tabla_inicial = pd.read_csv('tabla_INICIAL.csv')
tabla_pedidos = pd.read_csv('tabla_PEDIDOS.csv')
tabla_articulos = pd.read_csv('tabla_ARTICULOS.csv')
tabla_clientes = pd.read_csv('tabla_CLIENTES.csv')

# %%
tabla_inicial
# Out:
#    id_pedido  id_cliente   nombre_cliente  id_artículo     artículo_marca  \
# 0          1         101    Patricia Díaz            1  chaqueta, marca A
# 1          2         102  Marta Gutierrez            2  chaqueta, marca B
# 2          3         103   Cristina López            3  pantalón, marca C
# 3          3         103   Cristina López            2  chaqueta, marca B
#
#    cantidad  precio_unitario
# 0         2               29
# 1         5               37
# 2         3               42
# 3         1               37

# %%
tabla_pedidos
# Out:
#             PK Unnamed: 1          FK         FK.1 Unnamed: 4
# 0  id_registro  id_pedido  id_cliente  id_artículo   cantidad
# 1           01          1         101            1          2
# 2           02          2         102            2          5
# 3           03          3         103            3          3
# 4           04          3         103            2          1

# %%
tabla_articulos
# Out:
#             PK Unnamed: 1 Unnamed: 2       Unnamed: 3
# 0  id_artículo   artículo      marca  precio_unitario
# 1            1   chaqueta    marca A               29
# 2            2   chaqueta    marca B               37
# 3            3   pantalón    marca C               42

# %%
tabla_clientes
# Out:
#            PK      Unnamed: 1        Unnamed: 2
# 0  id_cliente  nombre_cliente  apellido_cliente
# 1         101        Patricia              Díaz
# 2         102           Marta         Gutierrez
# 3         103        Cristina             López
