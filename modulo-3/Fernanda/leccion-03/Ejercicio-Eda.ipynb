# %% [markdown]
# Ejercicios
# 1- Abrid el fichero de rating-and-performance con el método que sea más correcto (este archivo deberias haberlo descargado en el tema anterior).
#
# 2- Mostrad las 10 últimas filas.
#
# 3- Mostrad 5 filas aleatorias del DataFrame.
#
# 4- ¿Cuántas filas y columnas tenemos en el DataFrame?
#
# 5- ¿Cuáles son los nombres de las columnas del DataFrame?
#
# 6- Seleccionad solo las columnas de tipo categórico del DataFrame. Después, mostrad los valores únicos y sus frecuencias para cada una de las columnas seleccionadas.
#
# 7- En el DataFrame tenemos dos columnas que parece que nos dan la misma información "title" y "title_orig". Eliminad "title".
#
# 8- ¿En que columnas tenemos valores nulos? Utilizad el método que más os guste.
#
# 9- ¿Tenemos valores duplicados en el DataFrame?

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# %%
# 1. 
# cargamos el csv con el que vamos a ir desarrollando la lección de hoy, recordad que la descripción la tenéis al inicio del jupyter. 
# para eso usaremos el método "pd.read_csv" que ya vimos al inicio del módulo 2 cuando aprendimos las herramientas de web scrapping
df = pd.read_csv("rating-and-performance.csv", index_col = 0)

# hacemos un ".head()" para mostrar las 5 primeras filas del dataframe
df.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
# 2                EUR         100               0    3.57            14
# 3                EUR        5000               1    4.03           579
# 4                EUR         100               1    3.10            20
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 0                   26.0  ...                    568         4.128521
# 1                 2269.0  ...                  17752         3.899673
# 2                    5.0  ...                    295         3.989831
# 3                  295.0  ...                  23832         4.020435
# 4                    6.0  ...                  14482         4.001588
#
#                     merchant_id  merchant_has_profile_picture  \
# index
# 0      595097d6a26f6e070cb878d1                             0
# 1      56458aa03a698c35c9050988                             0
# 2      5d464a1ffdf7bc44ee933c65                             0
# 3      58cfdefdacb37b556efdff7c                             0
# 4      5ab3b592c3911a095ad5dadb                             0
#
#        merchant_profile_picture  \
# index
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                            product_url  \
# index
# 0      https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
# 1      https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2      https://www.wish.com/c/5ea10e2c617580260d55310a
# 3      https://www.wish.com/c/5cedf17ad1d44c52c59e4aca
# 4      https://www.wish.com/c/5ebf5819ebac372b070b0e70
#
#                                          product_picture  \
# index
# 0      https://contestimg.wish.com/api/webimage/5e9ae...
# 1      https://contestimg.wish.com/api/webimage/58940...
# 2      https://contestimg.wish.com/api/webimage/5ea10...
# 3      https://contestimg.wish.com/api/webimage/5cedf...
# 4      https://contestimg.wish.com/api/webimage/5ebf5...
#
#                      product_id   theme crawl_month
# index
# 0      5e9ae51d43d6a96e303acdb0  summer     2020-08
# 1      58940d436a0d3d5da4e95a38  summer     2020-08
# 2      5ea10e2c617580260d55310a  summer     2020-08
# 3      5cedf17ad1d44c52c59e4aca  summer     2020-08
# 4      5ebf5819ebac372b070b0e70  summer     2020-08
#
# [5 rows x 43 columns]

# %%
# recordemos que también tenemos el método ".tail()", el cual nos mostrará las últimas 10 filas del dataframe
df.tail(10)
# Out:
#                                                    title  \
# index
# 1563   ZANZEA Femmes Été Polka Dot Kaftan Beach Club ...
# 1564   2018 Femme mode d'été en dentelle Patchwork Pa...
# 1565   Nouveau Pantalon De Mode D'été Femmes Leggings...
# 1566   Robe mi-longue d'été à manches courtes pour fe...
# 1567   Combinaison sans manches pour femmes couleur u...
# 1568   Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569   10 couleurs femmes shorts d'été lacent ceintur...
# 1570   Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571   Mode femmes d'été sans manches robes col en V ...
# 1572   Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                               title_orig  price  retail_price  \
# index
# 1563   ZANZEA Women Summer Polka Dot Kaftan Beach Clu...  15.00            92
# 1564   2018 Women fashion Summer Lace Patchwork Tank ...   5.91             5
# 1565   New Summer Fashion Trousers Women Leggings Rip...   3.00             8
# 1566   Womens Short Sleeve Baggy Summer Beach Midi Dr...  11.00           134
# 1567   Sleeveless Solid Color Women Jumpsuit Ladies S...   8.00             7
# 1568   New Fashion Women Bohemia Dandelion Print Tee ...   6.00             9
# 1569   10 Color Women Summer Shorts Lace Up Elastic W...   2.00            56
# 1570   New Men Siwmwear Beach-Shorts Men Summer Quick...   5.00            19
# 1571   Fashion Women Summer Sleeveless Dresses V Neck...  13.00            11
# 1572   Fashion Women Yoga Pants Slim Fit Fitness Runn...   7.00             6
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 1563             EUR         100               0    3.51            74
# 1564             EUR        1000               0    3.38           414
# 1565             EUR         100               1    3.79            57
# 1566             EUR         100               1    3.54            28
# 1567             EUR       20000               1    4.25          3127
# 1568             EUR       10000               1    4.08          1367
# 1569             EUR         100               1    3.07            28
# 1570             EUR         100               0    3.71            59
# 1571             EUR         100               0    2.50             2
# 1572             EUR         100               1    4.07            14
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 1563                26.0  ...                 151914         4.127921
# 1564               156.0  ...                  12134         3.866903
# 1565                25.0  ...                   4080         3.987990
# 1566                 7.0  ...                   1926         4.071651
# 1567              1919.0  ...                  16803         4.155032
# 1568               722.0  ...                   5316         4.224605
# 1569                11.0  ...                   4435         3.696054
# 1570                24.0  ...                    210         3.961905
# 1571                 0.0  ...                     31         3.774194
# 1572                 8.0  ...                   7023         4.235939
#
#                     merchant_id  merchant_has_profile_picture  \
# index
# 1563   53aa664438d3046ee44a5024                             0
# 1564   58aec90823ef726994a323fe                             0
# 1565   584a7a381591451e4e3af3df                             0
# 1566   593402ae25c4f54ed4e0abdf                             0
# 1567   56455b13b15aab129db58cb7                             0
# 1568   5b507899ab577736508a0782                             0
# 1569   54d83b6b6b8a771e478558de                             0
# 1570   5b42da1bf64320209fc8da69                             0
# 1571   5d56b32c40defd78043d5af9                             0
# 1572   5a409cf87b584e7951b2e25f                             0
#
#        merchant_profile_picture  \
# index
# 1563                        NaN
# 1564                        NaN
# 1565                        NaN
# 1566                        NaN
# 1567                        NaN
# 1568                        NaN
# 1569                        NaN
# 1570                        NaN
# 1571                        NaN
# 1572                        NaN
#
#                                            product_url  \
# index
# 1563   https://www.wish.com/c/5da04c1f5949a226113006f1
# 1564   https://www.wish.com/c/5b4ed29514f0765a8a844592
# 1565   https://www.wish.com/c/5e8f0165e815903d022a3c7c
# 1566   https://www.wish.com/c/5d1060d39ed281190dfcec91
# 1567   https://www.wish.com/c/5c91a7ae7cfe8e4e64c36d97
# 1568   https://www.wish.com/c/5d5fadc99febd9356cbc52ee
# 1569   https://www.wish.com/c/5eccd22b4497b86fd48f16b4
# 1570   https://www.wish.com/c/5e74be96034d613d42b52dfe
# 1571   https://www.wish.com/c/5eda07ab0e295c2097c36590
# 1572   https://www.wish.com/c/5e857321f53c3d2d8f25e7ed
#
#                                          product_picture  \
# index
# 1563   https://contestimg.wish.com/api/webimage/5da04...
# 1564   https://contestimg.wish.com/api/webimage/5b4ed...
# 1565   https://contestimg.wish.com/api/webimage/5e8f0...
# 1566   https://contestimg.wish.com/api/webimage/5d106...
# 1567   https://contestimg.wish.com/api/webimage/5c91a...
# 1568   https://contestimg.wish.com/api/webimage/5d5fa...
# 1569   https://contestimg.wish.com/api/webimage/5eccd...
# 1570   https://contestimg.wish.com/api/webimage/5e74b...
# 1571   https://contestimg.wish.com/api/webimage/5eda0...
# 1572   https://contestimg.wish.com/api/webimage/5e857...
#
#                      product_id   theme crawl_month
# index
# 1563   5da04c1f5949a226113006f1  summer     2020-08
# 1564   5b4ed29514f0765a8a844592  summer     2020-08
# 1565   5e8f0165e815903d022a3c7c  summer     2020-08
# 1566   5d1060d39ed281190dfcec91  summer     2020-08
# 1567   5c91a7ae7cfe8e4e64c36d97  summer     2020-08
# 1568   5d5fadc99febd9356cbc52ee  summer     2020-08
# 1569   5eccd22b4497b86fd48f16b4  summer     2020-08
# 1570   5e74be96034d613d42b52dfe  summer     2020-08
# 1571   5eda07ab0e295c2097c36590  summer     2020-08
# 1572   5e857321f53c3d2d8f25e7ed  summer     2020-08
#
# [10 rows x 43 columns]

# %%
# ¿y si quisieramos ver "5" filas al azar de nuestro conjunto de datos? Podemos usar el método ".sample()", el cual por defecto nos devuelve solo una fila
df.sample(5)
# Out:
#                                                    title  \
# index
# 662    2020 été nouvelle mode femmes Tie-dye dégradé ...
# 1043   Tissu taille formateur gilet chaud shaper été ...
# 1026   Femmes Jupe longue Wave Point V-tie Robe à fou...
# 201    T-shirt d'été sans manches en coton imprimé "B...
# 266    Pantalon à lacets à la mode pour femmes d'été,...
#
#                                               title_orig  price  retail_price  \
# index
# 662    2020 Summer New Fashion Women's Tie-dye Gradie...    8.0             7
# 1043   Fabric Waist Trainer Vest Hot Shaper Summer Sh...    8.0            26
# 1026   Women Long Skirt Wave Point V-tie Open-fork Dr...   12.0            59
# 201    4 Colors Summer Women Fashion Sleeveless Cotto...    7.0            56
# 266    Summer Women s  Fashion  Lace Up Tie Pants  Pl...    6.0            26
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 662              EUR        1000               0    3.91           102
# 1043             EUR         100               0    3.07            14
# 1026             EUR         100               0    3.59            64
# 201              EUR        5000               1    4.16          1378
# 266              EUR         100               0    3.25            12
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 662                 50.0  ...                   2076         4.097303
# 1043                 3.0  ...                     43         3.186047
# 1026                24.0  ...                   5244         4.013921
# 201                747.0  ...                  25222         4.001546
# 266                  2.0  ...                     99         3.646465
#
#                     merchant_id  merchant_has_profile_picture  \
# index
# 662    59c7610621064f2f6c8c9fe7                             1
# 1043   5e4a06cb57cc9b1700e826b3                             0
# 1026   5acdbf7c9c15ff7191aadd30                             0
# 201    566a47bfe9fa8a31b3ef5141                             0
# 266    5e50fecf18034a89e1aeede8                             0
#
#                                 merchant_profile_picture  \
# index
# 662    https://s3-us-west-1.amazonaws.com/sweeper-pro...
# 1043                                                 NaN
# 1026                                                 NaN
# 201                                                  NaN
# 266                                                  NaN
#
#                                            product_url  \
# index
# 662    https://www.wish.com/c/5ea1a307f5df8f1f851fda62
# 1043   https://www.wish.com/c/5ea6bb4678212d0c01c3476a
# 1026   https://www.wish.com/c/5c944d690d06de6f91b3a991
# 201    https://www.wish.com/c/5b73bf7b7594b445df99384e
# 266    https://www.wish.com/c/5e6b0d747962cf365c8085dc
#
#                                          product_picture  \
# index
# 662    https://contestimg.wish.com/api/webimage/5ea1a...
# 1043   https://contestimg.wish.com/api/webimage/5ea6b...
# 1026   https://contestimg.wish.com/api/webimage/5c944...
# 201    https://contestimg.wish.com/api/webimage/5b73b...
# 266    https://contestimg.wish.com/api/webimage/5e6b0...
#
#                      product_id   theme crawl_month
# index
# 662    5ea1a307f5df8f1f851fda62  summer     2020-08
# 1043   5ea6bb4678212d0c01c3476a  summer     2020-08
# 1026   5c944d690d06de6f91b3a991  summer     2020-08
# 201    5b73bf7b7594b445df99384e  summer     2020-08
# 266    5e6b0d747962cf365c8085dc  summer     2020-08
#
# [5 rows x 43 columns]

# %%
# recordemos otro método que aprendimos al inicio del módulo 2, el método".shape" 
# que nos permitía saber cuántas filas y columnas tenemos en el DataFrame. 
# 📌 Recordemos que nos devuelve una tupla! donde su primer valor son las filas y el segundo valor las columnas.

print(f"El número de filas que tenemos es {df.shape[0]}, y el número de columnas es {df.shape[1]}")
# Out:
# El número de filas que tenemos es 1573, y el número de columnas es 43

# %%
# otro de los métodos que más usaremos es el método que nos devuelve el nombre de todas las columnas de nuestro DataFrame. Este es el método '.columns' 
# nos va a devolver un array con todos los nombres de las columnas
df.columns
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %%
# hagamos lo mismo para las columnas categóricas, para eso tendremos que incluir entre los paréntesis el parámetro include = "object"
df.describe(include = "object").T
# Out:
#                           count unique  \
# title                      1573   1201
# title_orig                 1573   1203
# currency_buyer             1573      1
# tags                       1573   1230
# product_color              1532    101
# product_variation_size_id  1559    106
# shipping_option_name       1573     15
# urgency_text                473      2
# origin_country             1556      6
# merchant_title             1573    958
# merchant_name              1569    957
# merchant_info_subtitle     1572   1058
# merchant_id                1573    958
# merchant_profile_picture    226    125
# product_url                1573   1341
# product_picture            1573   1341
# product_id                 1573   1341
# theme                      1573      1
# crawl_month                1573      1
#
#                                                                          top  \
# title                      Nouvelle mode d'été femmes robe décontractée c...
# title_orig                 New Fashion Summer Women Casual Dress Round Ne...
# currency_buyer                                                           EUR
# tags                       Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...
# product_color                                                          black
# product_variation_size_id                                                  S
# shipping_option_name                                      Livraison standard
# urgency_text                                              Quantité limitée !
# origin_country                                                            CN
# merchant_title                          guangzhouweishiweifushiyouxiangongsi
# merchant_name                                                    广州唯适唯服饰有限公司
# merchant_info_subtitle                     83 % avis positifs (32,168 notes)
# merchant_id                                         558c2cdc89d53c4005ea2920
# merchant_profile_picture   https://s3-us-west-1.amazonaws.com/sweeper-pro...
# product_url                  https://www.wish.com/c/5e16cb87e6dd7c03be24b28a
# product_picture            https://contestimg.wish.com/api/webimage/5e16c...
# product_id                                          5e16cb87e6dd7c03be24b28a
# theme                                                                 summer
# crawl_month                                                          2020-08
#
#                            freq
# title                        24
# title_orig                   24
# currency_buyer             1573
# tags                         17
# product_color               302
# product_variation_size_id   641
# shipping_option_name       1508
# urgency_text                472
# origin_country             1516
# merchant_title               15
# merchant_name                15
# merchant_info_subtitle       14
# merchant_id                  15
# merchant_profile_picture     12
# product_url                   3
# product_picture               3
# product_id                    3
# theme                      1573
# crawl_month                1573

# %%
# eliminamos las columnas que no son de nuestro interés usando el método '.drop()'
# pasándolo una lista con las columnas que queremos eliminar
# axis = 1 porque los nombres que le hemos pasado en la lista corresponden a las columnas
# inplace = True porque queremos que los cambios realizados se sobreescriban en el DataFrame
df.drop(['title'], axis = 1, inplace=True)

# chuequeamos como se ha quedado el DataFrame y vemos que ya lo tenemos preparado para poder evaluar cuales son sus valores únicos ('.unique()') y sus frecuencias ('.value_counts()')
df.head()
# Out:
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
# 2                EUR         100               0    3.57            14
# 3                EUR        5000               1    4.03           579
# 4                EUR         100               1    3.10            20
#
#        rating_five_count  rating_four_count  ...  merchant_rating_count  \
# index                                        ...
# 0                   26.0                8.0  ...                    568
# 1                 2269.0             1027.0  ...                  17752
# 2                    5.0                4.0  ...                    295
# 3                  295.0              119.0  ...                  23832
# 4                    6.0                4.0  ...                  14482
#
#        merchant_rating               merchant_id  \
# index
# 0             4.128521  595097d6a26f6e070cb878d1
# 1             3.899673  56458aa03a698c35c9050988
# 2             3.989831  5d464a1ffdf7bc44ee933c65
# 3             4.020435  58cfdefdacb37b556efdff7c
# 4             4.001588  5ab3b592c3911a095ad5dadb
#
#        merchant_has_profile_picture  merchant_profile_picture  \
# index
# 0                                 0                       NaN
# 1                                 0                       NaN
# 2                                 0                       NaN
# 3                                 0                       NaN
# 4                                 0                       NaN
#
#                                            product_url  \
# index
# 0      https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
# 1      https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2      https://www.wish.com/c/5ea10e2c617580260d55310a
# 3      https://www.wish.com/c/5cedf17ad1d44c52c59e4aca
# 4      https://www.wish.com/c/5ebf5819ebac372b070b0e70
#
#                                          product_picture  \
# index
# 0      https://contestimg.wish.com/api/webimage/5e9ae...
# 1      https://contestimg.wish.com/api/webimage/58940...
# 2      https://contestimg.wish.com/api/webimage/5ea10...
# 3      https://contestimg.wish.com/api/webimage/5cedf...
# 4      https://contestimg.wish.com/api/webimage/5ebf5...
#
#                      product_id   theme crawl_month
# index
# 0      5e9ae51d43d6a96e303acdb0  summer     2020-08
# 1      58940d436a0d3d5da4e95a38  summer     2020-08
# 2      5ea10e2c617580260d55310a  summer     2020-08
# 3      5cedf17ad1d44c52c59e4aca  summer     2020-08
# 4      5ebf5819ebac372b070b0e70  summer     2020-08
#
# [5 rows x 42 columns]

# %%
# ¿Cuántos valores nulos tenemos en la tabla ?
# en este caso usaremos el método '.isnull()'
# como vemos nos devuelve una Serie que recordemos es una estructura de datos unidimensional que contiene datos etiquetados y se asemeja a una columna de un DataFrame
df.isnull()
# Out:
#        title_orig  price  retail_price  currency_buyer  units_sold  \
# index
# 0           False  False         False           False       False
# 1           False  False         False           False       False
# 2           False  False         False           False       False
# 3           False  False         False           False       False
# 4           False  False         False           False       False
# ...           ...    ...           ...             ...         ...
# 1568        False  False         False           False       False
# 1569        False  False         False           False       False
# 1570        False  False         False           False       False
# 1571        False  False         False           False       False
# 1572        False  False         False           False       False
#
#        uses_ad_boosts  rating  rating_count  rating_five_count  \
# index
# 0               False   False         False              False
# 1               False   False         False              False
# 2               False   False         False              False
# 3               False   False         False              False
# 4               False   False         False              False
# ...               ...     ...           ...                ...
# 1568            False   False         False              False
# 1569            False   False         False              False
# 1570            False   False         False              False
# 1571            False   False         False              False
# 1572            False   False         False              False
#
#        rating_four_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 0                  False  ...                  False            False
# 1                  False  ...                  False            False
# 2                  False  ...                  False            False
# 3                  False  ...                  False            False
# 4                  False  ...                  False            False
# ...                  ...  ...                    ...              ...
# 1568               False  ...                  False            False
# 1569               False  ...                  False            False
# 1570               False  ...                  False            False
# 1571               False  ...                  False            False
# 1572               False  ...                  False            False
#
#        merchant_id  merchant_has_profile_picture  merchant_profile_picture  \
# index
# 0            False                         False                      True
# 1            False                         False                      True
# 2            False                         False                      True
# 3            False                         False                      True
# 4            False                         False                      True
# ...            ...                           ...                       ...
# 1568         False                         False                      True
# 1569         False                         False                      True
# 1570         False                         False                      True
# 1571         False                         False                      True
# 1572         False                         False                      True
#
#        product_url  product_picture  product_id  theme  crawl_month
# index
# 0            False            False       False  False        False
# 1            False            False       False  False        False
# 2            False            False       False  False        False
# 3            False            False       False  False        False
# 4            False            False       False  False        False
# ...            ...              ...         ...    ...          ...
# 1568         False            False       False  False        False
# 1569         False            False       False  False        False
# 1570         False            False       False  False        False
# 1571         False            False       False  False        False
# 1572         False            False       False  False        False
#
# [1573 rows x 42 columns]

# %%
# ¿tenemos duplicados teniendo en cuenta todas las filas del DataFrame?
# al igual que en el caso del '.isnull()' nos devuelve una serie de Booleanos
df.duplicated()
# Out:
# index
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1568    False
# 1569    False
# 1570    False
# 1571    False
# 1572    False
# Length: 1573, dtype: bool
